# %% [markdown]
# <a href="https://colab.research.google.com/github/ronakbihani123/NLP/blob/main/NLP_test_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# why do we remove stopwords in nlp? can removing stopwords ever reduce model performance ?

# %%
# stopwords are common words in nlp like "is" , "this" , "in" "and"
# removing stopwords can improve the performance of the model
# resons::
# 1. Reduce noise
# 2. model capture the important words
# 3. model accuracy improves and faster processing
# 4. traditional models like BERT and GPT works better after removing stopwords

# yes removing stopwords can reduce the model performance
# because in sentiment analysis
# words like "not" , "too" , "very" can change the sentiment of words
# which can reduce the model performance

# %%
# why do we use embedding instead of direct word ids in nlp

# %%
# if two words have the same meaning how can nlp model detect their similarity ?

# %%
# nlp detects word with similar meaning using word embeddings and contextual learning , where semantically similar words
# have similar vector representation

# %%
# why does class imbalance affect nlp models?

# %%
# class imbalance affect nlp models because the model becomes biased towards the majority class
# and performs poorly on the minority class

# %%
# what is out of vocabulary problem important in nlp ?

# %%
# out of vocabulary is a problem in nlp because the model cannot represent and understand word which were not seen during
# training which can reduce accuracy and context understanding

# %%
# what problem occur when the vocabulary size become very large ?

# %%
# a large vocabulary increases memory and computation cost , creates sparse representation , models overfitting and poor generalization /

# %%
# why is tokenization important in nlp?

# %%
# tokenization is important in nlp because it breaks raw text into smaller pieces making it possible for NLP model to process
# , analyse and convert text into numerical representation

# %%
# why do nlp model struggles with sarcasm detection?

# %%
# nlp model struggles with sarcasm because it requires understanding context , tone and intent while model mostly rely on literal
# word meanings

# %%
# why are word embeddings better than one hot encoding?

# %%
# word embeddings better than one hot encoding because they capture semantic meaning and relationship between words using dense vectors
# while one hot vectors are sparse and carry no contextual information

# %%
# why is tf-idf often better than count vectorization in many cases ?

# %%
# tf-idf is better than count vectorization because it considers both word frequency and word importance
# reducing the impact of common words and highlighting meaningful ones

# %%
# when should we use stemming instead of lemmatization ?

# %%
# we use stemming when we want fast processing , accuracy is not very critical ,
# working with large datasets
# ex - > search engines  , basic text - classification

# %%
# what do u mean by optimizers ? explain all optimizers in detail ?

# %%
# optimizers is an algorthm used to minize loss function or error by adjusting weight and biases
# of a neural network
